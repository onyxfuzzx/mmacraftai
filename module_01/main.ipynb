# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
print("test")
# Out:
# test

# %%
pd.read_csv("dataset/user_profiles.csv")
# Out:
#        id  user_id  age  gender  height_cm fitness_level     primary_goal  \
# 0       1        1   65    male     178.23  intermediate      weight_loss
# 1       2        2   51    male     159.82  intermediate      muscle_gain
# 2       3        3   20    male     174.95      beginner      muscle_gain
# 3       4        4   54    male     184.25      beginner      muscle_gain
# 4       5        5   33    male     172.12      beginner      weight_loss
# ..    ...      ...  ...     ...        ...           ...              ...
# 995   996      996   56  female     182.20  intermediate      muscle_gain
# 996   997      997   29  female     170.02  intermediate      muscle_gain
# 997   998      998   25  female     175.50      beginner  general_fitness
# 998   999      999   55  female     173.18      beginner      weight_loss
# 999  1000     1000   50    male     157.74  intermediate      muscle_gain
#
#                                    available_equipment  days_per_week  \
# ...

# %%
pd.read_csv(r"C:\Users\zaid\Documents\mega_project\mmacraftai\module_01\dataset\user_progress.csv")
# Out:
#           id  user_id    log_date  weight_kg  body_fat_percentage  \
# 0          1        1  2023-08-17       98.2                 30.3
# 1          2        1  2023-08-21       97.9                 10.1
# 2          3        1  2023-08-27       97.4                 30.9
# 3          4        1  2023-08-31       97.1                 20.8
# 4          5        1  2023-09-06       96.6                 32.9
# ...      ...      ...         ...        ...                  ...
# 12995  12996     1000  2024-07-05       68.8                 27.5
# 12996  12997     1000  2024-07-10       68.8                 34.6
# 12997  12998     1000  2024-07-18       69.2                 33.3
# 12998  12999     1000  2024-07-24       69.5                 10.5
# 12999  13000     1000  2024-07-30       69.4                 20.9
#
#                             measurements
# 0       {"waist_cm": 80, "chest_cm": 94}
# 1       {"waist_cm": 96, "chest_cm": 99}
# 2      {"waist_cm": 70, "chest_cm": 115}
# ...

# %%
pd.read_csv(r"dataset/users.csv")
# Out:
#        id          full_name                            email  \
# 0       1          Madhav De       madhav.de49@rediffmail.com
# 1       2      Varenya Johal        varenya.johal72@yahoo.com
# 2       3      Leela Kashyap        leela.kashyap16@gmail.com
# 3       4     Indrajit Doshi       indrajit.doshi40@gmail.com
# 4       5       Garima Bandi         garima.bandi81@gmail.com
# ..    ...                ...                              ...
# 995   996  Tanay Subramaniam  tanay.subramaniam34@hotmail.com
# 996   997       Kamala Balan         kamala.balan94@gmail.com
# 997   998    Baljiwan Thaman      baljiwan.thaman49@gmail.com
# 998   999       Harita Wason    harita.wason22@rediffmail.com
# 999  1000      Vansha Bansal   vansha.bansal21@rediffmail.com
#
#                                          password_hash  phone_number  \
# 0    cedbc15cf1567b81147fe2f994fa6007ffef2ced581a36...  910287180381
# 1    139300d935b1f2a4e9c974efa28e791a1c672224ce2de0...    2355405131
# ...

# %%
pd.read_csv(r"C:\Users\zaid\Documents\mega_project\mmacraftai\module_01\dataset\exercises.csv")
# Out:
#       id                                      exercise_name muscle_group  \
# 0      1                                         High Knees        Chest
# 1      2                                 Yoga: Downward Dog         Back
# 2      3         Heavy Bag Drill (Elbow Strike-Knee Strike)    Shoulders
# 3      4                   Kettlebell Close Grip Calf Raise         Back
# 4      5                                   Yoga: Plank Pose         Legs
# ..   ...                                                ...          ...
# 145  146                       Resistance Band Sumo Pull Up    Full Body
# 146  147                           Barbell Close Grip Lunge    Shoulders
# 147  148            Heavy Bag Drill (Elbow Strike-Uppercut)         Core
# 148  149  Shadow Boxing (Hook-Cross-Elbow Strike-Front K...    Full Body
# 149  150                        Kettlebell Jumping Deadlift         Core
#
#     exercise_type equipment_needed  base_weight_kg difficulty_level
# ...

# %%
pd.read_csv(r"C:\Users\zaid\Documents\mega_project\mmacraftai\module_01\dataset\workout_logs.csv")
# Out:
#           id  user_id       workout_name    log_date  duration_minutes  \
# 0          1        1       Legs Session  2023-08-17                36
# 1          2        1      Chest Session  2023-08-19                62
# 2          3        1  Full Body Session  2023-08-21                62
# 3          4        1      Chest Session  2023-08-24                41
# 4          5        1       Arms Session  2023-08-27                54
# ...      ...      ...                ...         ...               ...
# 24995  24996     1000       Back Session  2024-07-18                49
# 24996  24997     1000       Core Session  2024-07-20                59
# 24997  24998     1000      Chest Session  2024-07-24                48
# 24998  24999     1000       Legs Session  2024-07-28                37
# 24999  25000     1000       Arms Session  2024-07-30                57
#
#        perceived_exertion     user_notes
# 0                       8  Good session.
# ...

# %%
pd.read_csv(r"C:\Users\zaid\Documents\mega_project\mmacraftai\module_01\dataset\workout_log_details.csv")
# Out:
#             id  log_id  exercise_id  set_number  time_seconds  reps_completed  \
# 0            2       1           15           1          30.0             NaN
# 1            4       1           89           2          45.0             NaN
# 2            6       1          125           3          60.0             NaN
# 3            8       1            9           4          45.0             NaN
# 4           10       1          123           5          60.0             NaN
# ...        ...     ...          ...         ...           ...             ...
# 162426  324854   25000           33           3           NaN             8.0
# 162427  324856   25000           25           4          45.0             NaN
# 162428  324858   25000          126           5          60.0             NaN
# 162429  324860   25000          102           6          45.0             NaN
# 162430  324862   25000          142           7           NaN            10.0
#
#         weight_kg
# ...

# %%
# Data Same on Server
